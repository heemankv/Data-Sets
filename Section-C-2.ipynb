# %% [markdown]
# <a href="https://colab.research.google.com/github/heemankv/machine-learning/blob/main/Section-C-2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Importing various libraries to be used throught.
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import seaborn as sns

# Imporing the DataSet to be used.
df = pd.read_excel('/Dry_Bean_Dataset.xlsx')

# %%
sns.countplot(x=df['Class'])
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-ab1a0d50a804> in <module>
# ----> 1 sns.countplot(x=df['Class'])
#       2 plt.show()
#
# NameError: name 'sns' is not defined

# %%
# NoUse
sns.displot(data=df, x=df['Perimeter'], y=df['Class'])
plt.show(

# %%
sns.pairplot(data=df, hue='Class')
plt.show()

# %%
# missing data
total = df.isnull().sum().sort_values(ascending=False)
percent = (df.isnull().sum()/df.isnull().count()).sort_values(ascending=False)
missing_data =  pd.concat([total, percent], axis=1, keys=['Total', 'Percent'])
missing_data.head(100)
# Out:
#                  Total  Percent
# Area                 0      0.0
# Solidity             0      0.0
# ShapeFactor4         0      0.0
# ShapeFactor3         0      0.0
# ShapeFactor2         0      0.0
# ShapeFactor1         0      0.0
# Compactness          0      0.0
# roundness            0      0.0
# Extent               0      0.0
# Perimeter            0      0.0
# EquivDiameter        0      0.0
# ConvexArea           0      0.0
# Eccentricity         0      0.0
# AspectRation         0      0.0
# MinorAxisLength      0      0.0
# MajorAxisLength      0      0.0
# Class                0      0.0

# %%
sns.displot(df['Area'])
plt.show()

# %%
sns.boxplot(x=df['Area'])
plt.show()

# %%
fig, axes = plt.subplots(nrows = 4, ncols = 4)    # axes is 2d array (3x3)
axes = axes.flatten()         # Convert axes to 1d array of length 9
fig.set_size_inches(20, 20)

for ax, col in zip(axes, df.columns):
  sns.histplot(df[col], ax = ax)
# Out:
# Skewnewss: 2.952931
# Kurtosis: 10.800814
# Skewnewss: 1.626124
# Kurtosis: 3.588123
# Skewnewss: 1.357815
# Kurtosis: 2.531902
# Skewnewss: 2.238211
# Kurtosis: 6.651067
# Skewnewss: 0.582573
# Kurtosis: 0.113814
# Skewnewss: -1.062824
# Kurtosis: 1.387456
# Skewnewss: 2.941821
# Kurtosis: 10.743640
# Skewnewss: 1.948958
# Kurtosis: 5.192057
# Skewnewss: -0.895348
# Kurtosis: 0.643319
# Skewnewss: -2.550093
# Kurtosis: 12.799621
# Skewnewss: -0.635749
# Kurtosis: 0.374306
# Skewnewss: 0.037115
# Kurtosis: -0.223459
# Skewnewss: -0.534141
# Kurtosis: 0.714355
# Skewnewss: 0.301226
# Kurtosis: -0.859254
# Skewnewss: 0.242481
# Kurtosis: -0.144475
# Skewnewss: -2.759483
# Kurtosis: 13.038067

# %%
for ax, col in zip(axes, df.columns):
  print("Skewness of ", col, " is : " , df[col].skew())
  print("Kurtosis of ", col, " is : " , df[col].kurt())
# Out:
# Skewness of  Area  is :  2.9529309714284606
# Kurtosis of  Area  is :  10.800813973816409
# Skewness of  Perimeter  is :  1.6261235244866195
# Kurtosis of  Perimeter  is :  3.588123326632573
# Skewness of  MajorAxisLength  is :  1.357815283538504
# Kurtosis of  MajorAxisLength  is :  2.5319020623385935
# Skewness of  MinorAxisLength  is :  2.2382105396094616
# Kurtosis of  MinorAxisLength  is :  6.6510668036491225
# Skewness of  AspectRation  is :  0.582573399224162
# Kurtosis of  AspectRation  is :  0.11381444057675294
# Skewness of  Eccentricity  is :  -1.0628239308013614
# Kurtosis of  Eccentricity  is :  1.3874555963465989
# Skewness of  ConvexArea  is :  2.9418211110165506
# Kurtosis of  ConvexArea  is :  10.743640152020804
# Skewness of  EquivDiameter  is :  1.9489576095229233
# Kurtosis of  EquivDiameter  is :  5.192057256162549
# Skewness of  Extent  is :  -0.8953484282439236
# Kurtosis of  Extent  is :  0.6433188439711897
# Skewness of  Solidity  is :  -2.5500931076087867
# ...
